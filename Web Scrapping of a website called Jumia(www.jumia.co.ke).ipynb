# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

jumia = requests.get('https://www.jumia.co.ke/all-products/')

jumia.content
# Out:
# <ipython-input-1-5b25aefd6eca>:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# b'<!DOCTYPE html><html lang="en" dir="ltr"><head><meta charset="utf-8"/><title> Shop &amp; Buy Online | Jumia Kenya</title><meta property="og:type" content="product"/><meta property="og:site_name" content="Jumia Kenya"/><meta property="og:title" content=" Shop &amp; Buy Online | Jumia Kenya"/><meta property="og:url" content="/all-products/"/><meta property="og:image" content="https://ke.jumia.is/cms/icons/jumialogo-x-4.png"/><meta property="og:locale" content="en_KE"/><meta name="title" content=" Shop &amp; Buy Online | Jumia Kenya"/><meta name="robots" content="noindex,follow"/><link rel="alternate" href="android-app://com.jumia.android/JUMIA/KE/c/all-products?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.co.ke%2Fall-products%2F"/><link rel="canonical" href="https://www.jumia.co.ke/all-products/"/><link rel="next" href="https://www.jumia.co.ke/all-products/?page=2"/><meta property="fb:app_id" content="2099414773624117"/><meta property="fb:pages" content="395103207248808"/><meta name="google-site-verification" content="n_VPq2qj81eefHQXQuWUQcpCjf22dILtzJ-5fqwv3cY"/><meta name="google-site-verification" content="oPpguRNQpgJeq2_7FfJhfy4zTSNTJBX_LLPgB_SUq9g"/><meta name="msvalidate.01" content="18D4C7784A54CEB370A0B89D0634A096"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><meta name="application-name" content="Jumia"/><meta name="theme-color" content="#ffffff"/><link rel="manifest" crossorigin="use-credentials" href="https://www.jumia.co.ke/assets_he/manifest/jumia/ke.4f33d8aa.json"/><link rel="stylesheet" href="https://www.jumia.co.ke/assets_he/css/main.4d14222c.css"/><link rel="icon" type="image/ico" sizes="any" href="https://www.jumia.co.ke/assets_he/favicon.87f00114.ico"/><link rel="icon" type="image/svg+xml" href="https://www.jumia.co.ke/assets_he/favicon.adbd556a.svg"/><link rel="preconnect dns-prefetch" href="//bam.nr-data.net"/><link rel="preconnect dns-prefetch" href="//js-agent.newrelic.com"/><link rel="preconnect dns-prefetch" href="//www.google-analytics.com"/><link rel="preconnect dns-prefetch" href="//www.googletagmanager.com"/><link rel="preconnect dns-prefetch" href="//www.facebook.com"/><link rel="preconnect dns-prefetch" href="//connect.facebook.net"/><link rel="preconnect dns-prefetch" href="//static.criteo.net"/><link rel="preconnect dns-prefetch" href="//sslwidget.criteo.com"/><link rel="preconnect dns-prefetch" href="//dis.eu.criteo.com"/><link rel="preconnect dns-prefetch" href="//creativecdn.com"/><link rel="dns-prefetch" href="https://ke.jumia.is"/></head><body><script type=\'text/javascript\'>window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"200156797","agentToken":null,"applicationTime":127.259826,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFnVUFgMOVlIWHUY0LWpi","queueTime":0,"ttGuid":"aa6f120150b44b7d"}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"b76de0635f",applicationID:"200156797"};;/*! For license information please see nr-loader-rum-1.265.1.min.js.LICENSE.txt */\n(()=>{var e,t,r={8122:(e,t,r)=>{"use strict";r.d(t,{a:()=>i});var n=r(944);function i(e,t){try{if(!e||"object"!=typeof e)return(0,n.R)(3);if(!t||"object"!=typeof t)return(0,n.R)(4);const r=Object.create(Object.getPrototypeOf(t),Object.getOwnPropertyDescriptors(t)),o=0===Object.keys(r).length?e:r;for(let a in o)if(void 0!==e[a])try{if(null===e[a]){r[a]=null;continue}Array.isArray(e[a])&&Array.isArray(t[a])?r[a]=Array.from(new Set([...e[a],...t[a]])):"object"==typeof e[a]&&"object"==typeof t[a]?r[a]=i(e[a],t[a]):r[a]=e[a]}catch(e){(0,n.R)(1,e)}return r}catch(e){(0,n.R)(2,e)}}},2555:(e,t,r)=>{"use strict";r.d(t,{Vp:()=>c,fn:()=>s,x1:()=>u});var n=r(384),i=r(8122);const o={beacon:n.NT.beacon,errorBeacon:n.NT.errorBeacon,licenseKey:void 0 ...

# %%
for page in range(1,51):
  url = "https://www.jumia.co.ke/all-products/" + "?page=" +str(page)+"#catalog-listing"
  furl = requests.get(url)
  jsoup = BeautifulSoup(furl.content , 'html.parser')
  products = jsoup.find_all('div' , class_ = 'info')

  for product in products:
      Name = product.find('h3' , class_="name").text.replace('\n', '')
      Price = product.find('div' , class_= "prc").text.replace('\n', '')
      try:
        Rating = product.find('div', class_='stars _s').text.replace('\n', '')
      except:
        Rating = 'None'

      info = [ Name, Price,Rating]
      print(info)
# Out:
# ['Starlink Standard Actuated Kit', 'KSh 45,500', '4.7 out of 5']
# ['NIVEA Radiant & Beauty Advanced Care Lotion For Women - 400ml (Pack Of 2)', 'KSh 995', '4.4 out of 5']
# ["XIAOMI Redmi 13c, 6.47'',&nbsp; 256GB + 8GB RAM (Dual SIM) 5000mAh, 4G - Midnight Black", 'KSh 15,960', '4.6 out of 5']
# ['Nunix K1S Hot & Normal Standing Water Dispenser – White', 'KSh 3,465', '4.1 out of 5']
# ['NIVEA Perfect & Radiant Even Tone Day And Night Cream For Women - 50ml', 'KSh 1,199', '4.3 out of 5']
# ['NIVEA Pearl & Beauty Anti-Perspirant Rollon, 48h - 50ml (Pack Of 2)', 'KSh 702', '4.5 out of 5']
# ['VON VART-19DHS Double Door Fridge 136L - Silver (1YR WRTY)', 'KSh 27,500', '4.6 out of 5']
# ['Nunix Free standing Hot and Normal -Q7n White', 'KSh 3,685', '4 out of 5']
# ['Nunix 50 * 55cm Cookers 3 Gas, 1 Hotplate Electric Oven 3 Gas, Electric Oven(1YR WRTY)', 'KSh 22,550', '3.8 out of 5']
# ['Nunix AK-105 - 2 In 1 Blender With Grinding Machine – 350W -  1.5L – Black', 'KSh 1,680', '4.1 out of 5']
# ['Jameson Jameson Irish Whiskey - 750 Ml', 'KSh 2,199', '4.6 out of 5']
# ['Nunix AK-100 - 2 In 1 Blender With Grinding Machine - 1.5L', 'KSh 1,786', '4 out of 5']
# ['Vitron VB-815 - 2in1 Blender - 1.5L - 350W - White & Blue, (1YR WRTY)', 'KSh 1,660', '3.9 out of 5']
# ['Ramtons RM/553 - 21 Litre Tank Wet And Dry Vacuum Cleaner - Black (1YR WRTY)', 'KSh 12,434', '4.5 out of 5']
# ['Nunix Nunix 7.5KG Twins Tub Washing Machine', 'KSh 19,250', '4.3 out of 5']
# ['Nunix Free standing Hot and Normal Water Dispenser - Q7n White & Blue', 'KSh 3,630', '5 out of 5']
# ['Tecno POP 8, 6.6", 128GB + 4GB RAM (Extended to 8GB), 13MP, 4G (Dual SIM), 5000MAh - Mystery White', 'KSh 11,800', '4.2 out of 5']
# ['Rashnik Steel Cloth Drying Foldable Stand with Infinity Hooks', 'KSh 1,540', '3.7 out of 5']
# ['NIVEA Q10 Power Anti-Wrinkle Day Cream 50ml & Night Cream 50ml', 'KSh 2,858', '4.6 out of 5']
# ['Rashnik RN-2451 Hot And Normal Stand Alone Dispenser (White&Blue)', 'KSh 3,531', '3.6 out of 5']
# ["Blue Children's Toilet Seat 1-3-6 Years Old", 'KSh 602', '4.2 out of 5']
# ['Nunix NU-9090A 5.1 Woofer/mini Home Theatre Speaker System', 'KSh 13,420', '3.6 out of 5']
# ['NIVEA Perfect & Radiant Luminous630 Anti Dark Marks Serum, 30ml & Day Cream, 40ml', 'KSh 4,769', '4.4 out of 5']
# ['XIAOMI Redmi Note 13, 6.67", 128GB + 8GB RAM (Dual SIM), 5000mAh, Midnight Black', 'KSh 22,050', '5 out of 5']
# ['Nunix 20L Electric Rotisserie Oven, 1280W', 'KSh 4,852', '4 out of 5']
# ['NIVEA Lemongrass & Oil Shower Gel For Women - 250ml (Pack Of 2).', 'KSh 799', '4.6 out of 5']
# ['Soft Elastic Comfortable Wireless Music Headband--Black', 'KSh 703', '4.5 out of 5']
# ["Ballantine's Ballantine's Blended Scotch Whiskey - 750 Ml.", 'KSh 1,999', '4.6 out of 5']
# ['Hair Removal And Shaving USB Rechargeable Lint Remover', 'KSh 650', '4 out of 5']
# ['KISSKIDS Mini Pack Baby Diaper High Count Size 2 (3 - 6 Kg) 50 Pcs', 'KSh 503', '3.7 out of 5']
# ['NIVEA NIVEA SUN UV Face Blemish Control - 40ml', 'KSh 1,344', '4.5 out of 5']
# ['Baby Toilet Seat  Aid Cushion-Pink', 'KSh 602', '4 out of 5']
# ['Bathroom Storage Rack Kitchen Corner Rack Household Tripod', 'KSh 683', '5 out of 5']
# ['Itel A50 6.6" 64GB+2GB RAM, 5000mAh, Dual SIM, 4G - Misty Black (1YR WRTY)', 'KSh 8,670', '5 out of 5']
# ['Infinix Smart 8, 6.6", 64GB + 3GB RAM, 5000mAh, 4G, DUAL SIM - Timber Black', 'KSh 10,520', '5 out of 5']
# ['Itel A18 5.0", 32GB + 1GB RAM, 2400mAh -\xa0Morion Grey', 'KSh 5,800', 'None']
# ["Electric Mini Waterproof Shaver-USB Rechargeable Men's Travel", 'KSh 634', '3.3 out of 5']
# ['Oraimo OEP-650 Halo Airy Wired Earphone - Black', 'KSh 367', '4.2 out of 5']
# ['Itel A60s, 6.6", 64GB + 4GB RAM, Dual SIM, 5000mAh, 4G -?Glacier Green (1YR WRTY)', 'KSh 9,575', '5 out of 5']
# ['Itel 5082 - 2.4" - Tripple SIM - FM Wireless Radio - Black (1YR WRTY)', 'KSh 1,970', '4 out of 5']
# ['Ramtons RM/458 - Digital Glass Microwave (1YR WRTY)', 'KSh 10,979', '4.5 out of 5']
# ['Nunix Nunix 100 Litres Freezer Fridge', 'KSh 24,150', '4.2 out of 5']
# ['Fay Fay Kitchen Towels Twin Pack', 'KSh 209', '4.6 out of 5']
# ['Sundabest 6pc beer Glass Cups. (5112)', 'KSh 755', '4.6 out of 5']
# ['Nunix R5 Hot & Normal Free Standing Water Dispenser - White', 'KSh 3,990', '4 out of 5']
# ['Apple IPhone 11 - 6.1" - 128GB - 4GB RAM - 3110mAh - Black + 20W Charger (2YRs WRTY)', 'KSh 56,383', '3 out of 5']
# ['NIVEA MEN Black & White Original Anti-Perspirant Spray 48h - 150ml (Pack Of 2).', 'KSh 1,000', '4.6 out of 5']
# ['NIVEA Perfect & Radiant Luminous630 Anti Dark Marks Serum - 30ml-pack Of 2', 'KSh 5,381', '4.5 out of 5']
# ['Rashnik RN-8022 Solar Light 25w', 'KSh 2,200', '4.5 out of 5']
# ['Nunix NU-9090B 5.1 Woofer/mini Home Theatre Speaker System', 'KSh 12,699', '3.4 out of 5']
# ['Portable QC3.0 Multi-port 4USB Charger Black', 'KSh 395', '4.6 out of 5']
# ['Ramtons RF/130- 213l 2 Door Direct Cool Fridge+ Dispenser (1YR WRTY)', 'KSh 47,442', '5 out of 5']
# ['Itel IT9020, 2.0", 1000 mAh 4G - Lime Green', 'KSh 1,950', '4.7 out of 5']
# ['Dettol Dettol Soap Herbal 175g', 'KSh 199', '4.8 out of 5']
# ['Oraimo PowerCube 4 10.5W 4 Ports Wall Charger Kit_ Black', 'KSh 649', '5 out of 5']
# ['Hula Hoop Detachable&Adjustable Slim Waist Belt', 'KSh 962', 'None']
# ['Absolut Absolut Vodka Blue - 750ml', 'KSh 1,949', '4.5 out of 5']
# ["Children's Handheld Bazooka Bubble Machine----Pink", 'KSh 1,103', '3.7 out of 5']
# ['Royal 43" Smart Frameless Full HD LED Television - Black.', 'KSh 21,196', '4.2 out of 5']
# ['Watercolour Gold Foil Textured Print Pillow Cover', 'KSh 301', 'None']
# ['Retro&Nostalgic Pocket Gamer Nostalgia 400-in-1 -Black', 'KSh 794', '4 out of 5']
# ["Climbing Infrared Electric Children's Toy Rc Car--Red", 'KSh 958', 'None']
# ['Sundabest Plain White Decorated Dinner Plates 6 Pcs (311009774)', 'KSh 826', '3 out of 5']
# ['Nice & Lovely Bio Body Oil - 200ml', 'KSh 1,200', 'None']
# ['Door Seam Door Bottom Windproof Post-Door And Window Seals', 'KSh 367', 'None']
# ['Dental Products-Home Teeth Whitening Tools -Toothbrushes-Blue', 'KSh 247', 'None']
# ['Amtec AM-732 3.1CH Subwoofer Bluetooth System, FM/USB/SD - Black (1YR WRTY)', 'KSh 6,550', '4.6 out of 5']
# ['Removable Automatic Water Heater--White', 'KSh 995', 'None']
# ["Children's Handheld Bazooka Bubble Machine-Blue &Yellow", 'KSh 1,135', 'None']
# ['Gld G2303 5.1 Channel TallBoy Multimedia Speaker System 150W - Black', 'KSh 19,444', '4.4 out of 5']
# ["Oppo A58, 6.72'',50MP, 8GB+128GB, 4G, 5000mAh, Dual Stereo Speakers (Dual Sim)- Dazzling Green, (2YRs WRTY)", 'KSh 26,598', '4.2 out of 5']
# ['HD 40X60 Telescope With Phone Holder And Tripod', 'KSh 1,079', '4 out of 5']
# ["Light Up Sensor Magic Levitation Ball Children's Toys", 'KSh 547', 'None']
# ['New Fashion Business Mesh Strap Quartz Watch Black', 'KSh 533', 'None']
# ['Itel A05s 6.6", 32GB + 2GB RAM, Dual SIM, 4000mAh, 4G LTE -?Meadow Green (1YR WRTY)', 'KSh 8,499', 'None']
# ['Cute Key Cover Protective Bag-Leather Key Case-Green', 'KSh 173', '5 out of 5']
# ['Bluetooth Wireless Smart Watch- Black', 'KSh 1,034', 'None']
# ['Sundabest 6 Pcs Clear Glass Mug Set (11877)', 'KSh 1,073', '4 out of 5']
# ['Retro Nostalgic Mini Children Macaron Game Console-Green', 'KSh 903', '5 out of 5']
# ['Crystal Glass Home Wine Glass Whiskey', 'KSh 673', 'None']
